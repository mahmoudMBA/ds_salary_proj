# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
gd=pd.read_csv('Glassdoor_DS.csv')

# %%
gd.head()
# Out:
#                                    Company Name  \
# 0                                   Amrock\n3.6
# 1                                  ManTech\n4.1
# 2                                     Mars\n3.9
# 3  Parkland Center for Clinical Innovation\n4.2
# 4                       Affinity Solutions\n2.9
#
#                             Competitors  Founded  Headquarters  \
# 0                                    -1     1997   Detroit, MI
# 1                                    -1     1968   Herndon, VA
# 2                                    -1     1911   Mc Lean, VA
# 3                                    -1     2012    Dallas, TX
# 4  Commerce Signals, Cardlytics, Yodlee     1998  New York, NY
#
#                         Industry  \
# 0                    Real Estate
# 1         Research & Development
# 2  Food & Beverage Manufacturing
# 3                    IT Services
# 4        Advertising & Marketing
#
#                                      Job Description             Job Title  \
# ...

# %%
list(gd.columns)
# Out:
# ['Company Name',
#  'Competitors',
#  'Founded',
#  'Headquarters',
#  'Industry',
#  'Job Description',
#  'Job Title',
#  'Location',
#  'Rating',
#  'Revenue',
#  'Salary Estimate',
#  'Sector',
#  'Size',
#  'Type of ownership']

# %%
gd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
# Company Name         2000 non-null object
# Competitors          2000 non-null object
# Founded              2000 non-null int64
# Headquarters         2000 non-null object
# Industry             2000 non-null object
# Job Description      2000 non-null object
# Job Title            2000 non-null object
# Location             2000 non-null object
# Rating               2000 non-null float64
# Revenue              2000 non-null object
# Salary Estimate      2000 non-null object
# Sector               2000 non-null object
# Size                 2000 non-null object
# Type of ownership    2000 non-null object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 218.8+ KB

# %%
gd.shape
# Out:
# (2000, 14)

# %% [markdown]
# ### parse salary

# %%
gd['Salary Estimate'].value_counts()
# Out:
# $83K-$101K (Glassdoor est.)     275
# $36K-$85K (Glassdoor est.)       96
# $93K-$123K (Glassdoor est.)      64
# $92K-$101K (Glassdoor est.)      64
# $76K-$109K (Glassdoor est.)      64
# $59K-$97K (Glassdoor est.)       64
# $80K-$90K (Glassdoor est.)       64
# $31K-$63K (Glassdoor est.)       64
# $58K-$98K (Glassdoor est.)       64
# $121K-$147K (Glassdoor est.)     64
# $59K-$100K (Glassdoor est.)      64
# $61K-$99K (Glassdoor est.)       64
# $83K-$106K (Glassdoor est.)      64
# $74K-$124K (Glassdoor est.)      64
# $110K-$163K (Glassdoor est.)     64
# $53K-$71K (Glassdoor est.)       64
# $96K-$128K (Glassdoor est.)      64
# $61K-$77K (Glassdoor est.)       61
# $111K-$156K (Glassdoor est.)     32
# $61K-$97K (Glassdoor est.)       32
# $67K-$109K (Glassdoor est.)      32
# $109K-$152K (Glassdoor est.)     32
# $38K-$59K (Glassdoor est.)       32
# $94K-$139K (Glassdoor est.)      32
# $77K-$136K (Glassdoor est.)      32
# $125K-$141K (Glassdoor est.)     32
# ...

# %% [markdown]
# If we have an value in our dependant veriable we drop that line

# %%
gd=gd[gd['Salary Estimate']!='-1']

# %% [markdown]
# Remove (Glassdoor est.) from Salary Estimate

# %%
salary=gd['Salary Estimate'].apply(lambda x : x.split("(")[0] )

# %% [markdown]
# Replace the 'K' and '$' by  ""

# %%
salary=salary.apply(lambda x: x.replace("K","").replace('$',''))

# %% [markdown]
# Get the maximum,minimum and average salary and addd them to the data frame as integers

# %%
gd['min_salary']=salary.apply(lambda x:int(x.split('-')[0]))
gd['max_salary']=salary.apply(lambda x:int(x.split('-')[1]))
gd['avg_salary']=(min_salary+max_salary)/2

# %%
#gd[gd['Salary Estimate'].str.contains('Per Hour')]

# %% [markdown]
# ### Clean company name

# %%
gd[gd['Rating']==-1]
# Out:
#                                        Company Name Competitors  Founded  \
# 37                                  Bridgerock Data          -1       -1
# 118                                 Bridgerock Data          -1       -1
# 124                                        Decode_M          -1       -1
# 165                                  Get Me the Gig          -1     2017
# 182                               CA-One Tech Cloud          -1     2017
# 240                                  Seen by Indeed          -1       -1
# 259                                  Trovetechs Inc          -1       -1
# 303                               BlackLine Systems          -1       -1
# 305                               CA-One Tech Cloud          -1     2017
# 306                                            Bond          -1     2019
# 327                                     Trove Techs          -1       -1
# 345                                   Garner Health          -1       -1
# ...

# %%
gd['Company Name']=gd.apply(lambda x: x['Company Name'] if x['Rating']<0 else x['Company Name'][:-3],axis=1)

# %% [markdown]
# ### Separate city and state

# %%
gd['City']=gd['Location'].apply(lambda x:x.split(",")[0])

# %%
gd['State']=gd['Location'].apply(lambda x : x.split(',')[1] if len(x.split(','))>1 else x.split(',')[0]  )

# %%
gd[gd['State'].str.len()>3]['State'].value_counts()
# Out:
# Winnipeg           14
# New York State     12
# Toronto            10
# Remote              5
# Oregon              4
# North Vancouver     4
# United States       4
# Nebraska            3
# New Jersey          3
#  Los Angeles        2
# Edmonton            2
# Richmond            2
# Virginia            1
# California          1
# Maryland            1
# Poland              1
# Name: State, dtype: int64

# %%
#parse Revenue
#calculate company age
#parse the description
#parse company size
